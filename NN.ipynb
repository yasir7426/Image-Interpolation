# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

# Load and resize image
img = cv2.imread("0829x4.png")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_small = cv2.resize(img, (64, 64))

# Interpolate
nearest = cv2.resize(img_small, (256, 256), interpolation=cv2.INTER_NEAREST)
bilinear = cv2.resize(img_small, (256, 256), interpolation=cv2.INTER_LINEAR)
bicubic = cv2.resize(img_small, (256, 256), interpolation=cv2.INTER_CUBIC)

# Output folder
os.makedirs("interpolation_outputs", exist_ok=True)

# Save individual images (optional)
cv2.imwrite("interpolation_outputs/original.jpg", cv2.cvtColor(img, cv2.COLOR_RGB2BGR))
cv2.imwrite("interpolation_outputs/nearest.jpg", cv2.cvtColor(nearest, cv2.COLOR_RGB2BGR))
cv2.imwrite("interpolation_outputs/bilinear.jpg", cv2.cvtColor(bilinear, cv2.COLOR_RGB2BGR))
cv2.imwrite("interpolation_outputs/bicubic.jpg", cv2.cvtColor(bicubic, cv2.COLOR_RGB2BGR))

# Save plot with titles
titles = ["Original", "Nearest", "Bilinear", "Bicubic", "Lanczos"]
images = [img, nearest, bilinear, bicubic, lanczos]

plt.figure(figsize=(15, 6))
for i in range(4):
    plt.subplot(1, 4, i + 1)
    plt.imshow(images[i])
    plt.title(titles[i], fontsize=12, color='white')
    plt.axis('off')

plt.tight_layout()
plt.savefig("interpolation_outputs/comparison_plot_with_titles.png", dpi=300)
print("Plot saved with titles at 'interpolation_outputs/comparison_plot_with_titles.png'")
# Out:
# Plot saved with titles at 'interpolation_outputs/comparison_plot_with_titles.png'
